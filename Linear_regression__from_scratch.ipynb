# %% [markdown]
# <a href="https://colab.research.google.com/github/anoshandrews/Machismo/blob/main/Linear_regression__from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/salary_data.csv')
print(data)
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
plt.scatter(data.YearsExperience, data.Salary)

# %%
def loss_function(m,b, points):
  total_error =0
  for i in range(len(points)):
    x = points.iloc[i].YearsExperience
    y = points.iloc[i].Salary
    total_error += (y -(m*x+b))**2
  return total_error/float(len(points))
def gradient_descent(m_now,b_now, points,L):
  m_gradient = 0
  b_gradient = 0

  n = len(points)

  for i in range(n):
    x = points.iloc[i].YearsExperience
    y = points.iloc[i].Salary

    m_gradient += -(2/n)* x*(y -(m_now * x + b_now))
    b_gradient += -(2/n)* (y - (m_now * x + b_now))

  m = m_now - m_gradient * L
  b = b_now - b_gradient * L
  return m,b


m = 0
b = 0
L = 0.0001
epochs = 350

for i in range(epochs):
  if i % 50 == 0:
    current_loss = loss_function (m,b,data)

    print(f"Epoch:{i}, Loss:{current_loss}")
  m,b = gradient_descent(m,b, data,L)

print(m,b)
plt.scatter(data.YearsExperience,data.Salary)
plt.plot(list(range(1,12)),[m * x + b  for x in range(1,12)], color = 'red')
plt.show()
# Out:
# Epoch:0, Loss:169200000.0
# Epoch:50, Loss:133667576.68676881
# Epoch:100, Loss:105629953.4979051
# Epoch:150, Loss:83506257.1914596
# Epoch:200, Loss:66049067.0963593
# Epoch:250, Loss:52274080.17713921
# Epoch:300, Loss:41404611.8011138
# 2047.8408033166609 573.4604352570568

# %%
# Out:
# Epoch:0
# Epoch:50
# Epoch:100
# Epoch:150
# Epoch:200
# Epoch:250
# Epoch:300
# 0.0 0.0

# %%
import matplotlib.pyplot as plt
import pandas as pd

def loss_function(m, b, points):
    total_error = 0
    for i in range(len(points)):
        x = points.iloc[i].YearsExperience
        y = points.iloc[i].Salary
        total_error += (y - (m * x + b))**2
    return total_error / float(len(points))

def gradient_descent(m_now, b_now, points, L):
    m_gradient = 0
    b_gradient = 0
    n = len(points)

    for i in range(n):
        x = points.iloc[i].YearsExperience
        y = points.iloc[i].Salary

        m_gradient += -(2/n) * x * (y - (m_now * x + b_now))
        b_gradient += -(2/n) * (y - (m_now * x + b_now))

    m = m_now - m_gradient * L
    b = b_now - b_gradient * L
    return m, b

# Assuming you have a DataFrame named 'data' with columns 'YearsExperience' and 'Salary'
data = pd.DataFrame({'YearsExperience': [1, 2, 3, 4, 5],
                     'Salary': [6000, 8000, 11000, 15000, 20000]})

m = 0
b = 0
L = 0.0001
epochs = 350

for i in range(epochs):
    if i % 50 == 0:
        print(f"Epoch:{i}, Loss: {loss_function(m, b, data)}")
    m, b = gradient_descent(m, b, data, L)

print(f"Final parameters: m={m}, b={b}")

# Plot the regression line
plt.scatter(data.YearsExperience, data.Salary)
plt.plot(list(range(1, 6)), [m * x + b for x in range(1, 6)], color='red')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Linear Regression')
plt.show()
# Out:
# Epoch:0, Loss: 169200000.0
# Epoch:50, Loss: 133667576.68676881
# Epoch:100, Loss: 105629953.4979051
# Epoch:150, Loss: 83506257.1914596
# Epoch:200, Loss: 66049067.0963593
# Epoch:250, Loss: 52274080.17713921
# Epoch:300, Loss: 41404611.8011138
# Final parameters: m=2047.8408033166609, b=573.4604352570568
